# %%
import streamlit as st
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
st.title('Model Deployment')
st.write("project1-Ecommerce ")
# Out:
# 2024-03-06 17:24:42.871
# ...
#   command:
#
#     streamlit run C:\Users\Deepak\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
uploaded_file = st.file_uploader("Choose a CSV file", type="csv")

# %%
if uploaded_file is not None:
    data = pd.read_csv(uploaded_file)
else:
    st.info("Please upload a CSV file.")

# %%
st.sidebar.header("Content")
select_button = st.sidebar.selectbox("list",["View Dataset","EDA", "Visualization","Model Building"])

# %%
if select_button == "View Dataset":
    st.write("### Data from CSV File")
    st.write(data)
    
    st.write("## Ecommerce")
    st.write("""A project with an Ecommerce company sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want. The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They have asked to help them figure it out.

> Avg. Session Length: Average session of in-store style advice sessions in minutes.
> Time on App: Average time spent on App in minutes
> Time on Website: Average time spent on Website in minutes
> Length of Membership: How many years the customer has been a member.
> Yearly Amount Spent: The total amount the customer is spending in dollars.""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 if select_button == "View Dataset":
#       2     st.write("### Data from CSV File")
# ----> 3     st.write(data)
#       5     st.write("## Ecommerce")
#       6     st.write("""A project with an Ecommerce company sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want. The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They have asked to help them figure it out.
#       7
#       8 > Avg. Session Length: Average session of in-store style advice sessions in minutes.
#    (...)
# ...

# %%
if select_button == "EDA" :
    st.title("EDA")
    st.write("### The Shape of the data",data.shape)
    st.write("### The Size of dataset",data.size)
    st.write("### Descriptive Statistics of the data",data.describe())
    st.write("### Missing values in dataset",data.isnull().sum())
    st.write("### Checking Duplicate",data[data.duplicated()].sum())

# %%
if select_button == "Visualization":
    sns.pairplot(data)
    plt.show()
    st.pyplot(plt)
    
    # Correlation heatmap
    
    st.write("Correlation heatmap")
    sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
    plt.show()
    st.pyplot(plt)

    # Histogram of Avg Session Length
    st.write("Histogram of Avg Session Length")
    plt.figure(figsize=(8, 6))
    sns.histplot(data['Avg Session Length'], bins=20, kde=True)
    plt.title('Distribution of Avg Session Length')
    plt.xlabel('Avg Session Length')
    plt.ylabel('Frequency')
    plt.show()
    st.pyplot(plt)   

    # Histogram of Time on App
    st.write("Histogram of Time on App")
    plt.figure(figsize=(8, 6))
    sns.histplot(data['Time on App'], bins=20, kde=True)
    plt.title('Distribution of Time on App')
    plt.xlabel('Time on App')
    plt.ylabel('Frequency')
    plt.show()
    st.pyplot(plt)   

    # Histogram of Time on Website
    st.write("Histogram of Time on Website")
    plt.figure(figsize=(8, 6))
    sns.histplot(data['Time on Website'], bins=20, kde=True)
    plt.title('Distribution of Time on Website')
    plt.xlabel('Time on Website')
    plt.ylabel('Frequency')
    plt.show()
    st.pyplot(plt)       

    # Histogram of Length of Membership
    st.write("Histogram of Length of Membership")
    plt.figure(figsize=(8, 6))
    sns.histplot(data['Length of Membership'], bins=20, kde=True)
    plt.title('Distribution of Length of Membership')
    plt.xlabel('Length of Membership')
    plt.ylabel('Frequency')
    plt.show()
    st.pyplot(plt)
    # Scatter plot of Avg Session Length vs. Yearly Amount Spent
    st.write("Scatter plot of Avg Session Length vs. Yearly Amount Spent")
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=data, x='Avg Session Length', y='Yearly Amount Spent')
    plt.title('Scatter plot of Avg Session Length vs. Yearly Amount Spent')
    plt.xlabel('Avg Session Length')
    plt.ylabel('Yearly Amount Spent')
    plt.show()
    st.pyplot(plt)
    # 
    st.write("Scatter plot of Time on App vs. Yearly Amount Spent")
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=data, x='Time on App', y='Yearly Amount Spent')
    plt.title('Scatter plot of Time on App vs. Yearly Amount Spent')
    plt.xlabel('Time on App')
    plt.ylabel('Yearly Amount Spent')
    plt.show()
    st.pyplot(plt)
    # Scatter plot of Time on Website vs. Yearly Amount Spent
    st.write("Scatter plot of Time on Website vs. Yearly Amount Spent")
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=data, x='Time on Website', y='Yearly Amount Spent')
    plt.title('Scatter plot of Time on Website vs. Yearly Amount Spent')
    plt.xlabel('Time on Website')
    plt.ylabel('Yearly Amount Spent')
    plt.show()
    st.pyplot(plt)
    # Scatter plot of Length of Membership vs. Yearly Amount Spent
    st.write("Scatter plot of Length of Membership vs. Yearly Amount Spent")
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=data, x='Length of Membership', y='Yearly Amount Spent')
    plt.title('Scatter plot of Length of Membership vs. Yearly Amount Spent')
    plt.xlabel('Length of Membership')
    plt.ylabel('Yearly Amount Spent')
    plt.show()
    st.pyplot(plt)

# %%
if select_button == "Model Building":
    df1=data
    df2=df1.drop(columns=df1[['Email','Address','Avatar']],axis =1)
    X =df2.drop('Yearly Amount Spent',axis=1)
    Y= df2['Yearly Amount Spent']
    
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, Y, train_size=0.75, random_state=0)
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test= scaler.transform(X_test)
    y_train = scaler.fit_transform(y_train.values.reshape(-1, 1)).flatten()
    y_test = scaler.transform(y_test.values.reshape(-1, 1)).flatten()
    from sklearn.linear_model import LinearRegression
    from sklearn.metrics import r2_score, mean_squared_error
    from math import sqrt
    modell = LinearRegression()
    modell.fit(X_train, y_train)
    y_pred = modell.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = sqrt(mean_squared_error(y_test, y_pred))
    st.write("Linear Regression model R-squared Score:", r2)
    st.write("Linear Regression model Root Mean Squared Error (RMSE):", rmse)
    from sklearn.tree import DecisionTreeRegressor
    from sklearn.ensemble import RandomForestRegressor
    from sklearn.svm import SVR
    from sklearn.neighbors import KNeighborsRegressor
    from sklearn.linear_model import Ridge
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.neural_network import MLPRegressor
    models = [
        LinearRegression(),
    DecisionTreeRegressor(),
    RandomForestRegressor(),
    SVR(),
    KNeighborsRegressor(),
    Ridge(),
    GradientBoostingRegressor(),
    MLPRegressor()
    ]
    results_list = []
    for model in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        r2 = r2_score(y_test, y_pred)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        results_list.append({'Model': type(model).__name__, 'R2 Score': r2, 'RMSE': rmse})
        results_df = pd.DataFrame(results_list)
        st.write(results_df)                 
        coefficients = modell.coef_
        intercept = modell.intercept_
        st.write("Linear regression model Coefficients:", coefficients)
        st.write("Linear regression model Intercept:", intercept)
        plt.figure(figsize=(8, 6))
        plt.bar(X.columns, coefficients)
        plt.title('Linear Regression Coefficients',color='red')
        plt.xlabel('Features')
        plt.ylabel('Coefficient Values')
        plt.show()
        st.pyplot(plt)
        feature_names = ['Avg Session Length', 'Time on App', 'Time on Website', 'Length of Membership']
